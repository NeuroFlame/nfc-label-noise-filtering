# %% [markdown]
# ### Converting Original Dataset

# %%
import h5py

from utils.utils import load_fnc_h5

# %%
# %load_ext autoreload
# %autoreload 2

# %%
### PARAMETERS
SamplingThs = 0.7
iter = 101
ntree = 201
NI_threshold = 2
TypThs = 0.8
